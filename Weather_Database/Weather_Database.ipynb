# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low =-90.00, high = 90.00, size = 2000)
lngs = np.random.uniform(low = -180.00, high = 190.00, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 732

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
            
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),'Country':city_country,
                          'Lat':city_lat,'Lng':city_lng,
                          'Max Temp':city_max_temp,'Humidity':city_humidity,
                          'Cloudiness':city_clouds,'Wind Speed':city_wind,
                          'Current Description':city_weather_description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | lima
# Processing Record 5 of Set 1 | bababe
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | bengkulu
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | alberton
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | dunedin
# Processing Record 28 of Set 1 | esperance
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | anadyr
# Processing Record 31 of Set 1 | mogadishu
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | sao jose da coroa grande
# Processing Record 35 of Set 1 | tautira
# Processing Record 36 of Set 1 | shchelyayur
# City not found. Skipping...
# Processing Record 37 of Set 1 | marawi
# Processing Record 38 of Set 1 | gao
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | goundam
# Processing Record 41 of Set 1 | porto santo
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | cap malheureux
# Processing Record 44 of Set 1 | zhigansk
# Processing Record 45 of Set 1 | san vicente
# Processing Record 46 of Set 1 | rocha
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 1 | ahipara
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | garowe
# Processing Record 3 of Set 2 | shakhtinsk
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 6 of Set 2 | sharan
# Processing Record 7 of Set 2 | tanout
# Processing Record 8 of Set 2 | lasa
# Processing Record 9 of Set 2 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 10 of Set 2 | berbera
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | kiruna
# Processing Record 14 of Set 2 | tres arroyos
# Processing Record 15 of Set 2 | dingle
# Processing Record 16 of Set 2 | henties bay
# Processing Record 17 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | kankon
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | muroto
# Processing Record 26 of Set 2 | golden
# Processing Record 27 of Set 2 | hobyo
# Processing Record 28 of Set 2 | thinadhoo
# Processing Record 29 of Set 2 | pivijay
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 2 | colquechaca
# Processing Record 33 of Set 2 | zeya
# Processing Record 34 of Set 2 | skole
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | paita
# Processing Record 39 of Set 2 | cam ranh
# Processing Record 40 of Set 2 | noumea
# Processing Record 41 of Set 2 | abnub
# Processing Record 42 of Set 2 | kodinar
# Processing Record 43 of Set 2 | naze
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | north marysville
# City not found. Skipping...
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | marsaxlokk
# Processing Record 49 of Set 2 | aykhal
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | ostrovnoy
# Processing Record 2 of Set 3 | tel aviv-yafo
# Processing Record 3 of Set 3 | sao joao da barra
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | guerrero negro
# Processing Record 6 of Set 3 | monchegorsk
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | subaytilah
# City not found. Skipping...
# Processing Record 9 of Set 3 | kutum
# Processing Record 10 of Set 3 | grindavik
# Processing Record 11 of Set 3 | maldonado
# Processing Record 12 of Set 3 | villazon
# Processing Record 13 of Set 3 | tucurui
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | neyvo-shaytanskiy
# Processing Record 16 of Set 3 | liverpool
# Processing Record 17 of Set 3 | muscat
# Processing Record 18 of Set 3 | waipawa
# Processing Record 19 of Set 3 | alot
# Processing Record 20 of Set 3 | kruisfontein
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | charters towers
# Processing Record 23 of Set 3 | hami
# Processing Record 24 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 3 | bahia honda
# Processing Record 27 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 3 | fairbanks
# Processing Record 29 of Set 3 | batagay-alyta
# Processing Record 30 of Set 3 | aviles
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | abu kamal
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | jalu
# Processing Record 35 of Set 3 | kandrian
# Processing Record 36 of Set 3 | ajaccio
# Processing Record 37 of Set 3 | uvira
# Processing Record 38 of Set 3 | bollnas
# Processing Record 39 of Set 3 | yuzhou
# Processing Record 40 of Set 3 | saint-augustin
# Processing Record 41 of Set 3 | kelo
# Processing Record 42 of Set 3 | victor harbor
# Processing Record 43 of Set 3 | hovd
# Processing Record 44 of Set 3 | talaya
# Processing Record 45 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 3 | bubaque
# Processing Record 47 of Set 3 | adrar
# Processing Record 48 of Set 3 | kuytun
# Processing Record 49 of Set 3 | estelle
# Processing Record 50 of Set 3 | saint anthony
# Processing Record 1 of Set 4 | harper
# Processing Record 2 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 4 | kim
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | yinchuan
# Processing Record 6 of Set 4 | chumikan
# Processing Record 7 of Set 4 | phuket
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | ola
# Processing Record 10 of Set 4 | kalengwa
# Processing Record 11 of Set 4 | barrow
# Processing Record 12 of Set 4 | sabana abajo
# City not found. Skipping...
# Processing Record 13 of Set 4 | husum
# Processing Record 14 of Set 4 | zaraza
# Processing Record 15 of Set 4 | muisne
# Processing Record 16 of Set 4 | sao filipe
# Processing Record 17 of Set 4 | lompoc
# Processing Record 18 of Set 4 | pathalgaon
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | edd
# Processing Record 21 of Set 4 | axim
# Processing Record 22 of Set 4 | tripoli
# Processing Record 23 of Set 4 | numan
# Processing Record 24 of Set 4 | iqaluit
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | upernavik
# Processing Record 27 of Set 4 | grand gaube
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 4 | hilo
# Processing Record 31 of Set 4 | ilulissat
# Processing Record 32 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | camocim
# Processing Record 35 of Set 4 | cape town
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | athabasca
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 4 | ikongo
# Processing Record 42 of Set 4 | cotonou
# Processing Record 43 of Set 4 | okato
# Processing Record 44 of Set 4 | codrington
# Processing Record 45 of Set 4 | santa rosa de aguan
# Processing Record 46 of Set 4 | juneau
# Processing Record 47 of Set 4 | hirara
# Processing Record 48 of Set 4 | muros
# Processing Record 49 of Set 4 | hibbing
# Processing Record 50 of Set 4 | manturovo
# Processing Record 1 of Set 5 | askarovo
# Processing Record 2 of Set 5 | ampanihy
# Processing Record 3 of Set 5 | kieta
# Processing Record 4 of Set 5 | faya
# Processing Record 5 of Set 5 | longjiang
# Processing Record 6 of Set 5 | venafro
# Processing Record 7 of Set 5 | normandin
# Processing Record 8 of Set 5 | pokrovsk
# Processing Record 9 of Set 5 | viedma
# Processing Record 10 of Set 5 | flinders
# Processing Record 11 of Set 5 | quelimane
# Processing Record 12 of Set 5 | narsaq
# Processing Record 13 of Set 5 | xinzhi
# Processing Record 14 of Set 5 | isangel
# Processing Record 15 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 5 | yonago
# Processing Record 17 of Set 5 | souillac
# Processing Record 18 of Set 5 | galveston
# Processing Record 19 of Set 5 | baykalsk
# Processing Record 20 of Set 5 | liku
# Processing Record 21 of Set 5 | solton
# Processing Record 22 of Set 5 | dikson
# Processing Record 23 of Set 5 | rosignol
# Processing Record 24 of Set 5 | rundu
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | linxia
# Processing Record 27 of Set 5 | vila
# Processing Record 28 of Set 5 | najran
# Processing Record 29 of Set 5 | oksfjord
# Processing Record 30 of Set 5 | silchar
# Processing Record 31 of Set 5 | daru
# Processing Record 32 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | illapel
# Processing Record 35 of Set 5 | asau
# Processing Record 36 of Set 5 | rondonopolis
# Processing Record 37 of Set 5 | kloulklubed
# Processing Record 38 of Set 5 | thompson
# Processing Record 39 of Set 5 | dengzhou
# Processing Record 40 of Set 5 | udimskiy
# Processing Record 41 of Set 5 | katsuura
# Processing Record 42 of Set 5 | hammerfest
# Processing Record 43 of Set 5 | birin
# Processing Record 44 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 5 | tuatapere
# Processing Record 46 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 47 of Set 5 | cabo san lucas
# Processing Record 48 of Set 5 | jinxi
# Processing Record 49 of Set 5 | rio gallegos
# Processing Record 50 of Set 5 | mozarlandia
# Processing Record 1 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 2 of Set 6 | massaguet
# Processing Record 3 of Set 6 | coahuayana
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | auki
# Processing Record 6 of Set 6 | sibu
# Processing Record 7 of Set 6 | mehamn
# Processing Record 8 of Set 6 | porto novo
# Processing Record 9 of Set 6 | marquette
# Processing Record 10 of Set 6 | puerto escondido
# Processing Record 11 of Set 6 | puyang
# Processing Record 12 of Set 6 | nanakuli
# Processing Record 13 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 6 | shubarshi
# Processing Record 15 of Set 6 | havelian
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | coquimbo
# Processing Record 18 of Set 6 | itarema
# Processing Record 19 of Set 6 | praia da vitoria
# Processing Record 20 of Set 6 | mar del plata
# Processing Record 21 of Set 6 | barmer
# Processing Record 22 of Set 6 | yar-sale
# Processing Record 23 of Set 6 | hailey
# Processing Record 24 of Set 6 | chapais
# Processing Record 25 of Set 6 | gorin
# Processing Record 26 of Set 6 | ponta do sol
# Processing Record 27 of Set 6 | poum
# Processing Record 28 of Set 6 | carson city
# Processing Record 29 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 30 of Set 6 | wasilla
# Processing Record 31 of Set 6 | gardenstown
# Processing Record 32 of Set 6 | alta floresta
# Processing Record 33 of Set 6 | mingshui
# Processing Record 34 of Set 6 | geraldton
# Processing Record 35 of Set 6 | letka
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 38 of Set 6 | broome
# Processing Record 39 of Set 6 | san ramon
# Processing Record 40 of Set 6 | olinda
# Processing Record 41 of Set 6 | berlevag
# Processing Record 42 of Set 6 | kemijarvi
# Processing Record 43 of Set 6 | alice springs
# Processing Record 44 of Set 6 | pervomayskoye
# Processing Record 45 of Set 6 | torbay
# Processing Record 46 of Set 6 | lata
# Processing Record 47 of Set 6 | pangody
# Processing Record 48 of Set 6 | salalah
# Processing Record 49 of Set 6 | norden
# Processing Record 50 of Set 6 | bridlington
# Processing Record 1 of Set 7 | sinnamary
# Processing Record 2 of Set 7 | necochea
# Processing Record 3 of Set 7 | halifax
# Processing Record 4 of Set 7 | zinder
# Processing Record 5 of Set 7 | sergeyevka
# Processing Record 6 of Set 7 | pirmasens
# Processing Record 7 of Set 7 | torrijos
# Processing Record 8 of Set 7 | loandjili
# Processing Record 9 of Set 7 | roald
# Processing Record 10 of Set 7 | nizhniy baskunchak
# Processing Record 11 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 7 | wuwei
# Processing Record 13 of Set 7 | aksu
# Processing Record 14 of Set 7 | arua
# Processing Record 15 of Set 7 | kodiak
# Processing Record 16 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 17 of Set 7 | herat
# Processing Record 18 of Set 7 | dehloran
# Processing Record 19 of Set 7 | port lincoln
# Processing Record 20 of Set 7 | artyom
# Processing Record 21 of Set 7 | nabire
# Processing Record 22 of Set 7 | puerto colombia
# Processing Record 23 of Set 7 | puerto maldonado
# Processing Record 24 of Set 7 | yeppoon
# Processing Record 25 of Set 7 | hudson bay
# Processing Record 26 of Set 7 | termiz
# Processing Record 27 of Set 7 | ust-maya
# Processing Record 28 of Set 7 | dwarka
# Processing Record 29 of Set 7 | chokurdakh
# Processing Record 30 of Set 7 | ixtapa
# Processing Record 31 of Set 7 | rehoboth
# Processing Record 32 of Set 7 | jabinyanah
# Processing Record 33 of Set 7 | teahupoo
# Processing Record 34 of Set 7 | nicoya
# Processing Record 35 of Set 7 | hongjiang
# Processing Record 36 of Set 7 | cefalu
# Processing Record 37 of Set 7 | oulainen
# Processing Record 38 of Set 7 | pacific grove
# Processing Record 39 of Set 7 | deputatskiy
# Processing Record 40 of Set 7 | nantucket
# Processing Record 41 of Set 7 | asfi
# Processing Record 42 of Set 7 | arawa
# Processing Record 43 of Set 7 | pandan
# Processing Record 44 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 7 | synya
# Processing Record 46 of Set 7 | hervey bay
# Processing Record 47 of Set 7 | haimen
# Processing Record 48 of Set 7 | sur
# Processing Record 49 of Set 7 | ploemeur
# Processing Record 50 of Set 7 | buchanan
# Processing Record 1 of Set 8 | carutapera
# Processing Record 2 of Set 8 | comodoro rivadavia
# Processing Record 3 of Set 8 | san quintin
# Processing Record 4 of Set 8 | durango
# Processing Record 5 of Set 8 | erenhot
# Processing Record 6 of Set 8 | pangnirtung
# Processing Record 7 of Set 8 | saldanha
# Processing Record 8 of Set 8 | westport
# Processing Record 9 of Set 8 | mazamari
# Processing Record 10 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 11 of Set 8 | williams lake
# Processing Record 12 of Set 8 | vestmanna
# Processing Record 13 of Set 8 | the pas
# Processing Record 14 of Set 8 | bahia blanca
# Processing Record 15 of Set 8 | clyde river
# Processing Record 16 of Set 8 | atar
# Processing Record 17 of Set 8 | fonte boa
# Processing Record 18 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 20 of Set 8 | itoman
# Processing Record 21 of Set 8 | khonsa
# Processing Record 22 of Set 8 | abu samrah
# Processing Record 23 of Set 8 | dossor
# Processing Record 24 of Set 8 | riyadh
# Processing Record 25 of Set 8 | ribas do rio pardo
# Processing Record 26 of Set 8 | zemio
# Processing Record 27 of Set 8 | san patricio
# Processing Record 28 of Set 8 | aldan
# Processing Record 29 of Set 8 | ust-tsilma
# Processing Record 30 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 8 | fort-shevchenko
# Processing Record 32 of Set 8 | bartica
# Processing Record 33 of Set 8 | ancud
# Processing Record 34 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 35 of Set 8 | red wing
# Processing Record 36 of Set 8 | provideniya
# Processing Record 37 of Set 8 | moroto
# Processing Record 38 of Set 8 | clonakilty
# Processing Record 39 of Set 8 | talnakh
# Processing Record 40 of Set 8 | laguna
# Processing Record 41 of Set 8 | takoradi
# Processing Record 42 of Set 8 | umm kaddadah
# Processing Record 43 of Set 8 | devonport
# Processing Record 44 of Set 8 | petrivka
# Processing Record 45 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 8 | cutro
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | show low
# Processing Record 49 of Set 8 | chakulia
# Processing Record 50 of Set 8 | yulara
# Processing Record 1 of Set 9 | peniche
# Processing Record 2 of Set 9 | sibiti
# Processing Record 3 of Set 9 | amarante do maranhao
# Processing Record 4 of Set 9 | scarborough
# Processing Record 5 of Set 9 | hailar
# Processing Record 6 of Set 9 | maningrida
# Processing Record 7 of Set 9 | koster
# Processing Record 8 of Set 9 | meulaboh
# Processing Record 9 of Set 9 | balakhninskiy
# Processing Record 10 of Set 9 | morgaushi
# Processing Record 11 of Set 9 | belaya gora
# Processing Record 12 of Set 9 | chihuahua
# Processing Record 13 of Set 9 | sakakah
# Processing Record 14 of Set 9 | kavieng
# Processing Record 15 of Set 9 | toyo
# Processing Record 16 of Set 9 | bathsheba
# Processing Record 17 of Set 9 | alyangula
# Processing Record 18 of Set 9 | nalut
# Processing Record 19 of Set 9 | cape canaveral
# Processing Record 20 of Set 9 | kitimat
# Processing Record 21 of Set 9 | mehran
# Processing Record 22 of Set 9 | sao felix do xingu
# Processing Record 23 of Set 9 | saint-georges
# Processing Record 24 of Set 9 | benjamin constant
# Processing Record 25 of Set 9 | kot radha kishan
# Processing Record 26 of Set 9 | ribeira grande
# Processing Record 27 of Set 9 | kyra
# Processing Record 28 of Set 9 | mana
# Processing Record 29 of Set 9 | constitucion
# Processing Record 30 of Set 9 | ludvika
# Processing Record 31 of Set 9 | mackay
# Processing Record 32 of Set 9 | salinopolis
# Processing Record 33 of Set 9 | marrakesh
# Processing Record 34 of Set 9 | mareeba
# Processing Record 35 of Set 9 | bilovec
# Processing Record 36 of Set 9 | hambantota
# Processing Record 37 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 9 | mount gambier
# Processing Record 39 of Set 9 | rajshahi
# Processing Record 40 of Set 9 | bull savanna
# Processing Record 41 of Set 9 | dayong
# Processing Record 42 of Set 9 | pringsewu
# Processing Record 43 of Set 9 | olavarria
# Processing Record 44 of Set 9 | tambura
# Processing Record 45 of Set 9 | bad waldsee
# Processing Record 46 of Set 9 | hasaki
# Processing Record 47 of Set 9 | sao sebastiao
# Processing Record 48 of Set 9 | isla mujeres
# Processing Record 49 of Set 9 | damaturu
# Processing Record 50 of Set 9 | manta
# Processing Record 1 of Set 10 | maksatikha
# Processing Record 2 of Set 10 | thessalon
# Processing Record 3 of Set 10 | rovaniemi
# Processing Record 4 of Set 10 | kargasok
# Processing Record 5 of Set 10 | grand-santi
# Processing Record 6 of Set 10 | antsohihy
# Processing Record 7 of Set 10 | port macquarie
# Processing Record 8 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 9 of Set 10 | luanda
# Processing Record 10 of Set 10 | marsa matruh
# Processing Record 11 of Set 10 | innisfail
# Processing Record 12 of Set 10 | iquitos
# Processing Record 13 of Set 10 | severnoye
# Processing Record 14 of Set 10 | lumeje
# Processing Record 15 of Set 10 | sitka
# Processing Record 16 of Set 10 | olafsvik
# Processing Record 17 of Set 10 | monroe
# Processing Record 18 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 10 | tongren
# Processing Record 20 of Set 10 | oranjemund
# Processing Record 21 of Set 10 | tumut
# Processing Record 22 of Set 10 | west wendover
# Processing Record 23 of Set 10 | xining
# Processing Record 24 of Set 10 | saint-francois
# Processing Record 25 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 10 | governador valadares
# Processing Record 27 of Set 10 | jumla
# Processing Record 28 of Set 10 | dutlwe
# Processing Record 29 of Set 10 | saint-philippe
# Processing Record 30 of Set 10 | aborlan
# Processing Record 31 of Set 10 | hachinohe
# Processing Record 32 of Set 10 | haines junction
# Processing Record 33 of Set 10 | barguzin
# Processing Record 34 of Set 10 | ocampo
# Processing Record 35 of Set 10 | deer lake
# Processing Record 36 of Set 10 | euclides da cunha
# Processing Record 37 of Set 10 | ponta delgada
# Processing Record 38 of Set 10 | malakal
# Processing Record 39 of Set 10 | bardsir
# Processing Record 40 of Set 10 | bethel
# Processing Record 41 of Set 10 | dongsheng
# Processing Record 42 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 10 | sobolevo
# Processing Record 44 of Set 10 | koutiala
# Processing Record 45 of Set 10 | gloggnitz
# Processing Record 46 of Set 10 | kahului
# Processing Record 47 of Set 10 | ben tre
# Processing Record 48 of Set 10 | cocachacra
# Processing Record 49 of Set 10 | chukhloma
# Processing Record 50 of Set 10 | rabo de peixe
# Processing Record 1 of Set 11 | tolaga bay
# Processing Record 2 of Set 11 | nome
# Processing Record 3 of Set 11 | ulladulla
# Processing Record 4 of Set 11 | laibin
# Processing Record 5 of Set 11 | antalaha
# Processing Record 6 of Set 11 | san cristobal
# Processing Record 7 of Set 11 | requena
# Processing Record 8 of Set 11 | ajdabiya
# Processing Record 9 of Set 11 | antofagasta
# Processing Record 10 of Set 11 | bastia
# Processing Record 11 of Set 11 | nouadhibou
# Processing Record 12 of Set 11 | mpika
# Processing Record 13 of Set 11 | wajir
# Processing Record 14 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 15 of Set 11 | inirida
# Processing Record 16 of Set 11 | caucaia
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | lagoa
# Processing Record 19 of Set 11 | novo aripuana
# Processing Record 20 of Set 11 | vao
# Processing Record 21 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 11 | la ronge
# Processing Record 23 of Set 11 | auchel
# Processing Record 24 of Set 11 | skagen
# Processing Record 25 of Set 11 | kitob
# Processing Record 26 of Set 11 | port hueneme
# Processing Record 27 of Set 11 | sindgi
# Processing Record 28 of Set 11 | yermakovskoye
# Processing Record 29 of Set 11 | casper
# Processing Record 30 of Set 11 | lagos
# Processing Record 31 of Set 11 | eugene
# Processing Record 32 of Set 11 | monrovia
# Processing Record 33 of Set 11 | vila franca do campo
# Processing Record 34 of Set 11 | caravelas
# Processing Record 35 of Set 11 | letenye
# Processing Record 36 of Set 11 | yatou
# Processing Record 37 of Set 11 | korop
# Processing Record 38 of Set 11 | angelholm
# City not found. Skipping...
# Processing Record 39 of Set 11 | ternate
# Processing Record 40 of Set 11 | turochak
# Processing Record 41 of Set 11 | palmer
# Processing Record 42 of Set 11 | sola
# Processing Record 43 of Set 11 | buala
# Processing Record 44 of Set 11 | brae
# Processing Record 45 of Set 11 | atambua
# Processing Record 46 of Set 11 | makakilo city
# Processing Record 47 of Set 11 | coihaique
# Processing Record 48 of Set 11 | vestmannaeyjar
# Processing Record 49 of Set 11 | chengde
# Processing Record 50 of Set 11 | saint-prosper
# Processing Record 1 of Set 12 | sal rei
# Processing Record 2 of Set 12 | dosso
# Processing Record 3 of Set 12 | kajaani
# Processing Record 4 of Set 12 | saint andrews
# Processing Record 5 of Set 12 | beloha
# Processing Record 6 of Set 12 | chuka
# Processing Record 7 of Set 12 | niono
# Processing Record 8 of Set 12 | belomorsk
# Processing Record 9 of Set 12 | maniitsoq
# Processing Record 10 of Set 12 | bereda
# Processing Record 11 of Set 12 | namibe
# Processing Record 12 of Set 12 | durg
# Processing Record 13 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 12 | ewa beach
# Processing Record 15 of Set 12 | ballina
# Processing Record 16 of Set 12 | chifeng
# Processing Record 17 of Set 12 | diu
# Processing Record 18 of Set 12 | siare
# City not found. Skipping...
# Processing Record 19 of Set 12 | murgab
# Processing Record 20 of Set 12 | larsnes
# Processing Record 21 of Set 12 | shingu
# Processing Record 22 of Set 12 | boguchany
# Processing Record 23 of Set 12 | glace bay
# Processing Record 24 of Set 12 | sidmouth
# Processing Record 25 of Set 12 | rawson
# Processing Record 26 of Set 12 | lampa
# Processing Record 27 of Set 12 | omboue
# Processing Record 28 of Set 12 | kawalu
# Processing Record 29 of Set 12 | sinjai
# Processing Record 30 of Set 12 | micheweni
# Processing Record 31 of Set 12 | margate
# Processing Record 32 of Set 12 | ayan
# Processing Record 33 of Set 12 | biltine
# Processing Record 34 of Set 12 | nisia floresta
# Processing Record 35 of Set 12 | mercedes
# Processing Record 36 of Set 12 | wolfsburg
# Processing Record 37 of Set 12 | lake havasu city
# Processing Record 38 of Set 12 | jachymov
# Processing Record 39 of Set 12 | kviteseid
# Processing Record 40 of Set 12 | karratha
# Processing Record 41 of Set 12 | madras
# Processing Record 42 of Set 12 | avera
# Processing Record 43 of Set 12 | dalby
# Processing Record 44 of Set 12 | nioki
# Processing Record 45 of Set 12 | ucluelet
# Processing Record 46 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 12 | la peca
# Processing Record 48 of Set 12 | kabanjahe
# Processing Record 49 of Set 12 | mantua
# Processing Record 50 of Set 12 | sechura
# Processing Record 1 of Set 13 | pingliang
# Processing Record 2 of Set 13 | nanton
# Processing Record 3 of Set 13 | karamsad
# Processing Record 4 of Set 13 | mezen
# Processing Record 5 of Set 13 | shetpe
# Processing Record 6 of Set 13 | vilcun
# Processing Record 7 of Set 13 | hannibal
# Processing Record 8 of Set 13 | los llanos de aridane
# Processing Record 9 of Set 13 | lakatoro
# Processing Record 10 of Set 13 | oyama
# Processing Record 11 of Set 13 | taseyevo
# Processing Record 12 of Set 13 | sakaiminato
# Processing Record 13 of Set 13 | cabedelo
# Processing Record 14 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 13 | andenes
# Processing Record 17 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 13 | kalmunai
# Processing Record 19 of Set 13 | te anau
# Processing Record 20 of Set 13 | bandar-e lengeh
# Processing Record 21 of Set 13 | tabou
# Processing Record 22 of Set 13 | katherine
# Processing Record 23 of Set 13 | ust-nera
# Processing Record 24 of Set 13 | sheridan
# Processing Record 25 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 13 | iroquois falls
# Processing Record 27 of Set 13 | portland
# Processing Record 28 of Set 13 | emerald
# Processing Record 29 of Set 13 | igrim
# Processing Record 30 of Set 13 | alofi
# Processing Record 31 of Set 13 | sabang
# Processing Record 32 of Set 13 | dorokhovo
# Processing Record 33 of Set 13 | saryg-sep
# Processing Record 34 of Set 13 | bambanglipuro
# Processing Record 35 of Set 13 | dawlatabad
# Processing Record 36 of Set 13 | andros town
# Processing Record 37 of Set 13 | okhotsk
# Processing Record 38 of Set 13 | lavrentiya
# Processing Record 39 of Set 13 | the valley
# Processing Record 40 of Set 13 | ugoofaaru
# Processing Record 41 of Set 13 | ozernovskiy
# Processing Record 42 of Set 13 | kuching
# Processing Record 43 of Set 13 | flin flon
# Processing Record 44 of Set 13 | lagunas
# Processing Record 45 of Set 13 | mount pleasant
# Processing Record 46 of Set 13 | phan thiet
# Processing Record 47 of Set 13 | namatanai
# Processing Record 48 of Set 13 | lakes entrance
# Processing Record 49 of Set 13 | mayumba
# Processing Record 50 of Set 13 | puerto varas
# Processing Record 1 of Set 14 | eskisehir
# Processing Record 2 of Set 14 | grand forks
# Processing Record 3 of Set 14 | fort nelson
# Processing Record 4 of Set 14 | wilmington
# Processing Record 5 of Set 14 | sheltozero
# Processing Record 6 of Set 14 | pio xii
# Processing Record 7 of Set 14 | rawlins
# Processing Record 8 of Set 14 | lazaro cardenas
# Processing Record 9 of Set 14 | strezhevoy
# Processing Record 10 of Set 14 | kautokeino
# Processing Record 11 of Set 14 | tessalit
# Processing Record 12 of Set 14 | phalombe
# Processing Record 13 of Set 14 | yarkovo
# Processing Record 14 of Set 14 | barcelos
# Processing Record 15 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 14 | campbell river
# Processing Record 17 of Set 14 | lamu
# Processing Record 18 of Set 14 | buraydah
# Processing Record 19 of Set 14 | pilas
# Processing Record 20 of Set 14 | touba
# Processing Record 21 of Set 14 | vinh long
# Processing Record 22 of Set 14 | shache
# Processing Record 23 of Set 14 | choya
# Processing Record 24 of Set 14 | solina
# Processing Record 25 of Set 14 | nortelandia
# Processing Record 26 of Set 14 | egvekinot
# Processing Record 27 of Set 14 | simbahan
# Processing Record 28 of Set 14 | husavik
# Processing Record 29 of Set 14 | sumbe
# Processing Record 30 of Set 14 | abha
# Processing Record 31 of Set 14 | cortez
# Processing Record 32 of Set 14 | otane
# Processing Record 33 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 14 | port augusta
# Processing Record 35 of Set 14 | figeac
# Processing Record 36 of Set 14 | bolobo
# Processing Record 37 of Set 14 | borlange
# City not found. Skipping...
# Processing Record 38 of Set 14 | khani
# Processing Record 39 of Set 14 | cansancao
# Processing Record 40 of Set 14 | callaway
# Processing Record 41 of Set 14 | lesozavodsk
# Processing Record 42 of Set 14 | stephenville
# Processing Record 43 of Set 14 | miraflores
# Processing Record 44 of Set 14 | gamboma
# Processing Record 45 of Set 14 | kozhva
# Processing Record 46 of Set 14 | jawhar
# Processing Record 47 of Set 14 | broken hill
# Processing Record 48 of Set 14 | kudahuvadhoo
# Processing Record 49 of Set 14 | kamenka
# Processing Record 50 of Set 14 | magadan
# Processing Record 1 of Set 15 | palauig
# Processing Record 2 of Set 15 | hay river
# Processing Record 3 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 15 | richards bay
# Processing Record 5 of Set 15 | banyuwangi
# Processing Record 6 of Set 15 | tabas
# Processing Record 7 of Set 15 | new philadelphia
# Processing Record 8 of Set 15 | springhill
# Processing Record 9 of Set 15 | terney
# Processing Record 10 of Set 15 | kastornoye
# Processing Record 11 of Set 15 | morag
# Processing Record 12 of Set 15 | vorokhta
# Processing Record 13 of Set 15 | sisimiut
# Processing Record 14 of Set 15 | acapulco
# Processing Record 15 of Set 15 | padang
# Processing Record 16 of Set 15 | biskamzha
# Processing Record 17 of Set 15 | disna
# Processing Record 18 of Set 15 | karla
# Processing Record 19 of Set 15 | baherden
# Processing Record 20 of Set 15 | mouzakion
# City not found. Skipping...
# Processing Record 21 of Set 15 | izhma
# Processing Record 22 of Set 15 | hofn
# Processing Record 23 of Set 15 | dasoguz
# Processing Record 24 of Set 15 | mbandaka
# Processing Record 25 of Set 15 | komsomolskiy
# Processing Record 26 of Set 15 | kirakira
# Processing Record 27 of Set 15 | orlik
# Processing Record 28 of Set 15 | oktyabrskoye
# Processing Record 29 of Set 15 | ouro preto do oeste
# Processing Record 30 of Set 15 | ust-kuyga
# Processing Record 31 of Set 15 | manokwari
# Processing Record 32 of Set 15 | maloshuyka
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 669

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Tuktoyaktuk      CA  69.4541 -133.0374      6.67        93
# 1             Butaritari      KI   3.0707  172.7902     80.96        69
# 2              Hithadhoo      MV  -0.6000   73.0833     81.88        74
# 3                   Lima      PE -12.0432  -77.0282     66.90        81
# 4                Rikitea      PF -23.1203 -134.9692     72.12        84
# ..                   ...     ...      ...       ...       ...       ...
# 664                Orlik      RU  52.5178   99.8250     -2.20        56
# 665         Oktyabrskoye      RU  43.0645   44.7417     32.14       100
# 666  Ouro Preto Do Oeste      BR -10.7481  -62.2158     70.97        98
# 667            Ust-Kuyga      RU  70.0167  135.6000    -43.96        99
# 668            Manokwari      ID  -0.8667  134.0833     84.16        71
#
#      Cloudiness  Wind Speed Current Description
# 0           100        8.32     overcast clouds
# 1            11        2.82          few clouds
# 2            60       13.85       broken clouds
# 3             0        6.91           clear sky
# 4            99        9.13          light rain
# ..          ...         ...                 ...
# 664          51        9.60       broken clouds
# 665          60        4.47                 fog
# 666         100        2.77          light rain
# 667         100        4.79     overcast clouds
# 668         100       11.01     overcast clouds
#
# [669 rows x 9 columns]

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order =["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Tuktoyaktuk      CA  69.4541 -133.0374      6.67        93
# 1             Butaritari      KI   3.0707  172.7902     80.96        69
# 2              Hithadhoo      MV  -0.6000   73.0833     81.88        74
# 3                   Lima      PE -12.0432  -77.0282     66.90        81
# 4                Rikitea      PF -23.1203 -134.9692     72.12        84
# ..                   ...     ...      ...       ...       ...       ...
# 664                Orlik      RU  52.5178   99.8250     -2.20        56
# 665         Oktyabrskoye      RU  43.0645   44.7417     32.14       100
# 666  Ouro Preto Do Oeste      BR -10.7481  -62.2158     70.97        98
# 667            Ust-Kuyga      RU  70.0167  135.6000    -43.96        99
# 668            Manokwari      ID  -0.8667  134.0833     84.16        71
#
#      Cloudiness  Wind Speed Current Description
# 0           100        8.32     overcast clouds
# 1            11        2.82          few clouds
# 2            60       13.85       broken clouds
# 3             0        6.91           clear sky
# 4            99        9.13          light rain
# ..          ...         ...                 ...
# 664          51        9.60       broken clouds
# 665          60        4.47                 fog
# 666         100        2.77          light rain
# 667         100        4.79     overcast clouds
# 668         100       11.01     overcast clouds
#
# [669 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
